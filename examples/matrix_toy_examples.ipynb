# %%
import jax
import jax.numpy as np
from jax import lax
from jax import scipy
import numpyro
import numpyro.distributions as dist
from numpyro.distributions import constraints
import matplotlib.pyplot as plt
import seaborn as sns
from numpyro_stein.autoguides import AutoDelta
from numpyro_stein.util import init_with_noise
import numpyro_stein.stein.kernels as kernels
from numpyro_stein.stein.stein import SVGD
from numpyro.infer import ELBO
from numpyro.infer.util import init_to_value
import numpy as onp

# %%
class Sine(dist.Distribution):
    support = constraints.real
    def __init__(self, alpha=np.array(1.), sigma1=np.array(3e-3), sigma2=np.array(1.0), validate_args=None):
        batch_shape = lax.broadcast_shapes(np.shape(alpha), np.shape(sigma1), np.shape(sigma2))
        self.alpha = np.broadcast_to(alpha, batch_shape)
        self.sigma1 = np.broadcast_to(sigma1, batch_shape)
        self.sigma2 = np.broadcast_to(sigma2, batch_shape)
        super(Sine, self).__init__(batch_shape=batch_shape, validate_args=validate_args)

    def log_prob(self, value):
        return - (value[..., 1] + np.sin(self.alpha * value[..., 0])) ** 2 / (2 * self.sigma1) -\
                (value[..., 0] ** 2 + value[..., 1] ** 2) / (2 * self.sigma2)

    def sample(self, key, sample_shape=()):
        xs = np.array(onp.linspace(-1, 1, num=100))
        ys = np.array(onp.linspace(-1, 1, num=100))
        zs = np.stack(np.meshgrid(xs, ys), axis=-1)
        logits = np.expand_dims(np.ravel(self.log_prob(zs)), axis=0)
        cs = dist.Categorical(logits=logits).sample(key, sample_shape)
        res = np.concatenate(np.divmod(cs, zs.shape[0]), axis=-1).astype('float') /\
              np.array([np.max(xs) - np.min(xs), np.max(ys) - np.min(ys)]) + np.array([np.min(xs), np.min(ys)])
        return res

# %%
sine_xs = np.linspace(-1, 1, num=100)
sine_ys = np.linspace(-1, 1, num=100)
sine_zs = np.stack(np.meshgrid(sine_xs, sine_ys), axis=-1)
sine_lps = np.exp(Sine().log_prob(sine_zs))
plt.imshow(sine_lps, origin='lower', interpolation='bicubic', extent=[np.min(sine_xs), np.max(sine_xs), 
                                                                      np.min(sine_ys), np.max(sine_ys)])
plt.show()

# %%
class DoubleBanana(dist.Distribution):
    support = constraints.real
    def __init__(self, y=np.log(30.), sigma1=np.array(1.0), sigma2=np.array(9e-2), validate_args=None):
        batch_shape = lax.broadcast_shapes(np.shape(y), np.shape(sigma1), np.shape(sigma2))
        self.y = np.broadcast_to(y, batch_shape)
        self.sigma1 = np.broadcast_to(sigma1, batch_shape)
        self.sigma2 = np.broadcast_to(sigma2, batch_shape)
        super(DoubleBanana, self).__init__(batch_shape=batch_shape, validate_args=validate_args)
    
    def log_prob(self, value):
        fx = np.log((1 - value[..., 0]) ** 2.0 + 100 * (value[..., 1] - value[..., 0] ** 2.0) ** 2.0)
        return - np.sqrt(value[..., 0] ** 2.0 + value[..., 1] ** 2.0) ** 2.0 / (2.0 * self.sigma1) -\
                 (self.y - fx) ** 2.0 / (2.0 * self.sigma2)

    
    def sample(self, key, sample_shape=()):
        xs = np.array(onp.linspace(-1.5, 1.5, num=100))
        ys = np.array(onp.linspace(-1, 2, num=100))
        zs = np.stack(np.meshgrid(xs, ys), axis=-1)
        logits = np.expand_dims(np.ravel(self.log_prob(zs)), axis=0)
        cs = dist.Categorical(logits=logits).sample(key, sample_shape)
        res = np.concatenate(np.divmod(cs, zs.shape[0]), axis=-1).astype('float') /\
              np.array([np.max(xs) - np.min(xs), np.max(ys) - np.min(ys)]) + np.array([np.min(xs), np.min(ys)])
        return res

# %%
xs = np.linspace(-1.5, 1.5, num=100)
ys = np.linspace(-1, 2, num=100)
zs = np.stack(np.meshgrid(xs, ys), axis=-1)
lps = np.exp(DoubleBanana().log_prob(zs))
plt.imshow(lps, origin='lower', interpolation='bicubic', extent=[np.min(xs), np.max(xs), np.min(ys), np.max(ys)])
plt.show()

# %%
class Star(dist.Distribution):
    support = constraints.real
    def __init__(self, mu0=np.array([0., 1.5]), cov0=np.diag(np.array([1e-2, 0.25])), n_comp=5, validate_args=None):
        batch_shape = lax.broadcast_shapes(np.shape(mu0)[:-1], np.shape(cov0)[:-2])
        mu0 = np.broadcast_to(mu0, batch_shape + np.shape(mu0)[-1:])
        cov0 = np.broadcast_to(cov0, batch_shape + np.shape(cov0)[-2:])
        self.n_comp = n_comp
        mus = [mu0]
        covs = [cov0]
        theta = 2 * np.pi / n_comp
        rot = np.array([[np.cos(theta), -np.sin(theta)], [np.sin(theta), np.cos(theta)]])
        for i in range(n_comp - 1):
            mui = rot @ mus[-1]
            covi = rot @ covs[-1] @ rot.transpose()
            mus.append(mui)
            covs.append(covi)
        self.mus = np.stack(mus)
        self.covs = np.stack(covs)
        super(Star, self).__init__(batch_shape=batch_shape, validate_args=validate_args)
    
    def log_prob(self, value):
        lps = []
        for i in range(self.n_comp):
            lps.append(dist.MultivariateNormal(self.mus[i], self.covs[i]).log_prob(value))
        return scipy.special.logsumexp(np.stack(lps, axis=0), axis=0) / self.n_comp

    def sample(self, key, sample_shape=()):
        print(key)
        zs = dist.Categorical(probs=np.array([1/self.n_comp] * self.n_comp)).sample(key, sample_shape)
        xs = np.stack([dist.MultivariateNormal(self.mus[i], self.covs[i]).sample(key, sample_shape) 
                       for i in range(self.n_comp)], axis=0)
        return np.take_along_axis(xs, np.expand_dims(np.expand_dims(zs, axis=-1), axis=-1), axis=0)

# %%
xs = np.linspace(-3, 3, num=100)
ys = np.linspace(-3, 3, num=100)
zs = np.stack(np.meshgrid(xs, ys), axis=-1)
lps = np.exp(Star().log_prob(zs))
plt.imshow(lps, origin='lower', interpolation='bicubic', extent=[np.min(xs), np.max(xs), np.min(ys), np.max(ys)])
plt.show()

# %%
rng_key = jax.random.PRNGKey(42)

# %% [markdown]
# # Sine Model

# %%
num_iterations = 30

# %%
def model():
    numpyro.sample('x', Sine())
guide = AutoDelta(model, init_strategy=init_with_noise(init_to_value({'x': np.array([0., 0.])}), noise_scale=1.0))

# %%
svgd = SVGD(model, guide, numpyro.optim.Adagrad(step_size=0.5), ELBO(),
            kernels.RBFKernel(), num_stein_particles=50, num_loss_particles=1)

# %%
svgd_state, loss = svgd.run(rng_key, num_iterations)
res = svgd.get_params(svgd_state)['auto_x']
plt.clf()
plt.scatter(res[..., 0], res[..., 1])
# Out:
# [ 895026564 2266944918]
# [1103547586 3522086544]
# SVGD 5.3147: 100%|██████████| 30/30 [00:12<00:00,  2.35it/s]

# %%
svgd = SVGD(model, guide, numpyro.optim.Adagrad(step_size=1.0), ELBO(),
            kernels.PrecondMatrixKernel(kernels.HessianPrecondMatrix(), kernels.RBFKernel(mode='matrix'),
                                        precond_mode='const'),
            num_stein_particles=50, num_loss_particles=1)

# %%
svgd_state, loss = svgd.run(rng_key, num_iterations)
res = svgd.get_params(svgd_state)['auto_x']
plt.clf()
plt.scatter(res[..., 0], res[..., 1])
# Out:
# [1103547586 3522086544]
# SVGD 14.371: 100%|██████████| 30/30 [00:09<00:00,  3.28it/s]

# %%
svgd = SVGD(model, guide, numpyro.optim.Adagrad(step_size=0.5), ELBO(),
            kernels.PrecondMatrixKernel(kernels.HessianPrecondMatrix(), kernels.RBFKernel(mode='matrix'),
                                        precond_mode='anchor_points'),
            num_stein_particles=50, num_loss_particles=1)

# %%
svgd_state, loss = svgd.run(rng_key, num_iterations)
res = svgd.get_params(svgd_state)['auto_x']
plt.clf()
plt.scatter(res[..., 0], res[..., 1])
# Out:
# [1103547586 3522086544]
# SVGD 9.3697: 100%|██████████| 30/30 [00:12<00:00,  2.33it/s]

# %% [markdown]
# # Double Banana Model

# %%
num_iterations = 100

# %%
def model():
    numpyro.sample('x', DoubleBanana())
guide = AutoDelta(model, init_strategy=init_with_noise(init_to_value({'x': np.array([0., 0.])}), noise_scale=3.0))

# %%
svgd = SVGD(model, guide, numpyro.optim.Adagrad(step_size=1.0), ELBO(),
            kernels.RBFKernel(), num_stein_particles=50, num_loss_particles=1)

# %%
svgd_state, loss = svgd.run(rng_key, num_iterations)
res = svgd.get_params(svgd_state)['auto_x']
plt.clf()
plt.scatter(res[..., 0], res[..., 1])
# Out:
# SVGD 6.4919: 100%|██████████| 100/100 [00:06<00:00, 15.72it/s]

# %%
svgd = SVGD(model, guide, numpyro.optim.Adagrad(step_size=1.0), ELBO(),
            kernels.PrecondMatrixKernel(kernels.HessianPrecondMatrix(), kernels.RBFKernel(mode='matrix'),
                                        precond_mode='const'),
            num_stein_particles=50, num_loss_particles=1)

# %%
svgd_state, loss = svgd.run(rng_key, num_iterations)
res = svgd.get_params(svgd_state)['auto_x']
plt.clf()
plt.scatter(res[..., 0], res[..., 1])
# Out:
# SVGD 4.8154: 100%|██████████| 100/100 [00:15<00:00,  6.27it/s]

# %%
svgd = SVGD(model, guide, numpyro.optim.Adagrad(step_size=.8), ELBO(),
            kernels.PrecondMatrixKernel(kernels.HessianPrecondMatrix(), kernels.RBFKernel(mode='matrix'),
                                        precond_mode='anchor_points'),
            num_stein_particles=50, num_loss_particles=1)

# %%
svgd_state, loss = svgd.run(rng_key, num_iterations)
res = svgd.get_params(svgd_state)['auto_x']
plt.clf()
plt.scatter(res[..., 0], res[..., 1])
# Out:
# SVGD 4.0935: 100%|██████████| 100/100 [00:24<00:00,  4.10it/s]

# %% [markdown]
# # Star Model

# %%
num_iterations = 60

# %%
def model():
    numpyro.sample('x', Star())
guide = AutoDelta(model, init_strategy=init_with_noise(init_to_value({'x': np.array([0., 0.])}), noise_scale=3.0))

# %%
svgd = SVGD(model, guide, numpyro.optim.Adagrad(step_size=1.0), ELBO(),
            kernels.RBFKernel(), num_stein_particles=50, num_loss_particles=1)

# %%
svgd_state, loss = svgd.run(rng_key, num_iterations)
res = svgd.get_params(svgd_state)['auto_x']
plt.clf()
plt.scatter(res[..., 0], res[..., 1])
# Out:
# SVGD 0.55555: 100%|██████████| 60/60 [00:07<00:00,  7.51it/s]

# %%
svgd = SVGD(model, guide, numpyro.optim.Adagrad(step_size=0.5), ELBO(),
            kernels.PrecondMatrixKernel(kernels.HessianPrecondMatrix(), kernels.RBFKernel(mode='matrix'),
                                        precond_mode='const'),
            num_stein_particles=50, num_loss_particles=1)

# %%
svgd_state, loss = svgd.run(rng_key, num_iterations)
res = svgd.get_params(svgd_state)['auto_x']
plt.clf()
plt.scatter(res[..., 0], res[..., 1])
# Out:
# SVGD 1.552: 100%|██████████| 60/60 [00:20<00:00,  2.95it/s]

# %%
svgd = SVGD(model, guide, numpyro.optim.Adagrad(step_size=0.8), ELBO(),
            kernels.PrecondMatrixKernel(kernels.HessianPrecondMatrix(), kernels.RBFKernel(mode='matrix'),
                                        precond_mode='anchor_points'),
            num_stein_particles=50, num_loss_particles=1)

# %%
svgd_state, loss = svgd.run(rng_key, num_iterations)
res = svgd.get_params(svgd_state)['auto_x']
plt.clf()
plt.scatter(res[..., 0], res[..., 1])
# Out:
# SVGD 0.43407: 100%|██████████| 60/60 [00:27<00:00,  2.17it/s]

# %%
svgd = SVGD(model, guide, numpyro.optim.Adagrad(step_size=0.8), ELBO(),
            kernels.RBFKernel(),
            num_stein_particles=50, num_loss_particles=1,
            num_mcmc_particles=5)

# %%
with jax.disable_jit():
    svgd_state, loss = svgd.run(rng_key, num_iterations)
res = svgd.get_params(svgd_state)['auto_x']
plt.clf()
plt.scatter(res[..., 0], res[..., 1])
# Out:
# [1103547586 3522086544]
#   0%|          | 0/60 [00:00<?, ?it/s]Traced<ShapedArray(uint32[2]):JaxprTrace(level=1/0)>
#   0%|          | 0/60 [00:00<?, ?it/s]None
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-36-0eeb6002c86a> in <module>
#       1 with jax.disable_jit():
# ----> 2     svgd_state, loss = svgd.run(rng_key, num_iterations)
#       3 res = svgd.get_params(svgd_state)['auto_x']
#       4 plt.clf()
#       5 plt.scatter(res[..., 0], res[..., 1])
#
# ~/Documents/SourceControl/numpyro_stein/numpyro_stein/stein/stein.py in run(self, rng_key, num_steps, return_last, progbar, *args, **kwargs)
#     297             with tqdm.trange(num_steps) as t:
#     298                 for i in t:
# --> 299                     svgd_state, losses = jax.jit(bodyfn)(i, (svgd_state, losses))
#     300                     t.set_description('SVGD {:.5}'.format(losses[i]), refresh=False)
#     301                     t.update()
#
# /usr/local/Caskroom/miniconda/base/envs/numpyro-stein/lib/python3.8/site-packages/jax/api.py in f_jitted(*args, **kwargs)
#     129   def f_jitted(*args, **kwargs):
#     130     if _thread_local_state.jit_is_disabled or config.read('jax_disable_jit'):
# --> 131       return fun(*args, **kwargs)
#     132     if static_argnums and max(static_argnums) >= len(args):
#     133       msg = ("Jitted function has static_argnums={} but was called with only {}"
#
# ~/Documents/SourceControl/numpyro_stein/numpyro_stein/stein/stein.py in bodyfn(i, info)
#     287         def bodyfn(i, info):
#     288             svgd_state, losses = info
# --> 289             svgd_state, loss = self.update(svgd_state, *args, **kwargs)
#     290             losses = ops.index_update(losses, i, loss)
#     291             return svgd_state, losses
#
# ~/Documents/SourceControl/numpyro_stein/numpyro_stein/stein/stein.py in update(self, state, *args, **kwargs)
#     278         # Run Stein Point MCMC
#     279         if self.num_mcmc_particles > 0:
# --> 280             params = self._sp_mcmc(rng_key_mcmc, params, *args, **kwargs, **self.static_kwargs)
#     281         loss_val, grads = self._svgd_loss_and_grads(rng_key_step, params,
#     282                                                     *args, **kwargs, **self.static_kwargs)
#
# ~/Documents/SourceControl/numpyro_stein/numpyro_stein/stein/stein.py in _sp_mcmc(self, rng_key, unconstr_params, *args, **kwargs)
#     179         if self.mcmc._warmup_state is None:
#     180             stein_subset_uparams = {p: v[0:self.num_mcmc_particles] for p, v in stein_uparams.items()}
# --> 181             self.mcmc.warmup(warmup_key, *args, init_params=self.constrain_fn(stein_subset_uparams), **kwargs)
#     182
#     183         # 2. Choose MCMC particles
#
# /usr/local/Caskroom/miniconda/base/envs/numpyro-stein/lib/python3.8/site-packages/numpyro/infer/mcmc.py in warmup(self, rng_key, extra_fields, collect_warmup, init_params, *args, **kwargs)
#    1147         else:
#    1148             self._set_collection_params(self.num_warmup, self.num_warmup, self.num_samples)
# -> 1149         self.run(rng_key, *args, extra_fields=extra_fields, init_params=init_params, **kwargs)
#    1150         self._warmup_state = self._last_state
#    1151
#
# /usr/local/Caskroom/miniconda/base/envs/numpyro-stein/lib/python3.8/site-packages/numpyro/infer/mcmc.py in run(self, rng_key, extra_fields, init_params, *args, **kwargs)
#    1221                 states, last_state = map_fn((rng_key, init_state, init_params, args, kwargs))
#    1222             else:
# -> 1223                 states, last_state = map_fn((rng_key, init_state, init_params))
#    1224             if chain_method == 'vectorized':
#    1225                 # swap num_samples x num_chains to num_chains x num_samples
#
# /usr/local/Caskroom/miniconda/base/envs/numpyro-stein/lib/python3.8/site-packages/jax/lax/lax_control_flow.py in map(f, xs)
#    1205   """
#    1206   g = lambda _, x: ((), f(x))
# -> 1207   _, ys = scan(g, (), xs)
#    1208   return ys
#    1209
#
# /usr/local/Caskroom/miniconda/base/envs/numpyro-stein/lib/python3.8/site-packages/jax/lax/lax_control_flow.py in scan(f, init, xs, length)
#     789   x_dtypes = [x.dtype for x in xs_flat]
#     790   x_avals = tuple(_map(ShapedArray, x_shapes, x_dtypes))
# --> 791   jaxpr, consts, out_tree = _initial_style_jaxpr(f, in_tree, carry_avals + x_avals)
#     792   out_tree_children = out_tree.children()
#     793   if len(out_tree_children) != 2:
#
# /usr/local/Caskroom/miniconda/base/envs/numpyro-stein/lib/python3.8/site-packages/jax/lax/lax_control_flow.py in _initial_style_jaxpr(fun, in_tree, in_avals)
#      55   in_pvals = [pe.PartialVal((aval, core.unit)) for aval in in_avals]
#      56   fun, out_tree = flatten_fun_nokwargs(lu.wrap_init(fun), in_tree)
# ---> 57   jaxpr, out_pvals, consts = pe.trace_to_jaxpr(fun, in_pvals, instantiate=True,
#      58                                                stage_out_calls=True)
#      59   out_avals = _map(raise_to_shaped, unzip2(out_pvals)[0])
#
# /usr/local/Caskroom/miniconda/base/envs/numpyro-stein/lib/python3.8/site-packages/jax/interpreters/partial_eval.py in trace_to_jaxpr(fun, pvals, instantiate, stage_out_calls)
#     352   with new_master(trace_type) as master:
#     353     fun = trace_to_subjaxpr(fun, master, instantiate)
# --> 354     jaxpr, (out_pvals, consts, env) = fun.call_wrapped(pvals)
#     355     assert not env
#     356     del master
#
# /usr/local/Caskroom/miniconda/base/envs/numpyro-stein/lib/python3.8/site-packages/jax/linear_util.py in call_wrapped(self, *args, **kwargs)
#     147     gen = None
#     148
# --> 149     ans = self.f(*args, **dict(self.params, **kwargs))
#     150     del args
#     151     while stack:
#
# /usr/local/Caskroom/miniconda/base/envs/numpyro-stein/lib/python3.8/site-packages/jax/lax/lax_control_flow.py in <lambda>(_, x)
#    1204     Mapped values.
#    1205   """
# -> 1206   g = lambda _, x: ((), f(x))
#    1207   _, ys = scan(g, (), xs)
#    1208   return ys
#
# /usr/local/Caskroom/miniconda/base/envs/numpyro-stein/lib/python3.8/site-packages/numpyro/infer/mcmc.py in _single_chain_nojit_args(self, init, model_args, model_kwargs, collect_fields)
#    1103
#    1104     def _single_chain_nojit_args(self, init, model_args, model_kwargs, collect_fields=('z',)):
# -> 1105         return self._single_chain_mcmc(*init, model_args, model_kwargs, collect_fields=collect_fields)
#    1106
#    1107     def _set_collection_params(self, lower=None, upper=None, collection_size=None):
#
# /usr/local/Caskroom/miniconda/base/envs/numpyro-stein/lib/python3.8/site-packages/numpyro/infer/mcmc.py in _single_chain_mcmc(self, rng_key, init_state, init_params, args, kwargs, collect_fields)
#    1067     def _single_chain_mcmc(self, rng_key, init_state, init_params, args, kwargs, collect_fields=('z',)):
#    1068         if init_state is None:
# -> 1069             init_state = self.sampler.init(rng_key, self.num_warmup, init_params,
#    1070                                            model_args=args, model_kwargs=kwargs)
#    1071         if self.postprocess_fn is None:
#
# /usr/local/Caskroom/miniconda/base/envs/numpyro-stein/lib/python3.8/site-packages/numpyro/infer/mcmc.py in init(self, rng_key, num_warmup, init_params, model_args, model_kwargs)
#     531         )
#     532         if rng_key.ndim == 1:
# --> 533             init_state = hmc_init_fn(init_params, rng_key)
#     534         else:
#     535             # XXX it is safe to run hmc_init_fn under vmap despite that hmc_init_fn changes some
#
# /usr/local/Caskroom/miniconda/base/envs/numpyro-stein/lib/python3.8/site-packages/numpyro/infer/mcmc.py in <lambda>(init_params, rng_key)
#     516                                        "Please check your model again.")
#     517
# --> 518         hmc_init_fn = lambda init_params, rng_key: self._init_fn(  # noqa: E731
#     519             init_params,
#     520             num_warmup=num_warmup,
#
# /usr/local/Caskroom/miniconda/base/envs/numpyro-stein/lib/python3.8/site-packages/numpyro/infer/mcmc.py in init_kernel(init_params, num_warmup, step_size, inverse_mass_matrix, adapt_step_size, adapt_mass_matrix, dense_mass, target_accept_prob, trajectory_length, max_tree_depth, model_args, model_kwargs, rng_key)
#     255
#     256         rng_key_hmc, rng_key_wa, rng_key_momentum = random.split(rng_key, 3)
# --> 257         wa_state = wa_init(z, rng_key_wa, step_size,
#     258                            inverse_mass_matrix=inverse_mass_matrix,
#     259                            mass_matrix_size=np.size(z_flat))
#
# /usr/local/Caskroom/miniconda/base/envs/numpyro-stein/lib/python3.8/site-packages/numpyro/infer/hmc_util.py in init_fn(z, rng_key, step_size, inverse_mass_matrix, mass_matrix_size)
#     381
#     382         if adapt_step_size:
# --> 383             step_size = find_reasonable_step_size(inverse_mass_matrix, z, rng_key_ss, step_size)
#     384         ss_state = ss_init(np.log(10 * step_size))
#     385
#
# /usr/local/Caskroom/miniconda/base/envs/numpyro-stein/lib/python3.8/site-packages/numpyro/infer/hmc_util.py in find_reasonable_step_size(potential_fn, kinetic_fn, momentum_generator, inverse_mass_matrix, position, rng_key, init_step_size)
#     238     _, vv_update = velocity_verlet(potential_fn, kinetic_fn)
#     239     z = position
# --> 240     potential_energy, z_grad = value_and_grad(potential_fn)(z)
#     241     finfo = np.finfo(get_dtype(init_step_size))
#     242
#
# /usr/local/Caskroom/miniconda/base/envs/numpyro-stein/lib/python3.8/site-packages/jax/api.py in value_and_grad_f(*args, **kwargs)
#     405     f_partial, dyn_args = _argnums_partial(f, argnums, args)
#     406     if not has_aux:
# --> 407       ans, vjp_py = vjp(f_partial, *dyn_args)
#     408     else:
#     409       ans, vjp_py, aux = vjp(f_partial, *dyn_args, has_aux=True)
#
# /usr/local/Caskroom/miniconda/base/envs/numpyro-stein/lib/python3.8/site-packages/jax/api.py in vjp(fun, *primals, **kwargs)
#    1283   if not has_aux:
#    1284     flat_fun, out_tree = flatten_fun_nokwargs(fun, in_tree)
# -> 1285     out_primal, out_vjp = ad.vjp(flat_fun, primals_flat)
#    1286     out_tree = out_tree()
#    1287   else:
#
# /usr/local/Caskroom/miniconda/base/envs/numpyro-stein/lib/python3.8/site-packages/jax/interpreters/ad.py in vjp(traceable, primals, has_aux)
#     104 def vjp(traceable, primals, has_aux=False):
#     105   if not has_aux:
# --> 106     out_primals, pvals, jaxpr, consts = linearize(traceable, *primals)
#     107   else:
#     108     out_primals, pvals, jaxpr, consts, aux = linearize(traceable, *primals, has_aux=True)
#
# /usr/local/Caskroom/miniconda/base/envs/numpyro-stein/lib/python3.8/site-packages/jax/interpreters/ad.py in linearize(traceable, *primals, **kwargs)
#      93   _, in_tree = tree_flatten(((primals, primals), {}))
#      94   jvpfun_flat, out_tree = flatten_fun(jvpfun, in_tree)
# ---> 95   jaxpr, out_pvals, consts = pe.trace_to_jaxpr(jvpfun_flat, in_pvals)
#      96   pval_primals, pval_tangents = tree_unflatten(out_tree(), out_pvals)
#      97   aval_primals, const_primals = unzip2(pval_primals)
#
# /usr/local/Caskroom/miniconda/base/envs/numpyro-stein/lib/python3.8/site-packages/jax/interpreters/partial_eval.py in trace_to_jaxpr(fun, pvals, instantiate, stage_out_calls)
#     352   with new_master(trace_type) as master:
#     353     fun = trace_to_subjaxpr(fun, master, instantiate)
# --> 354     jaxpr, (out_pvals, consts, env) = fun.call_wrapped(pvals)
#     355     assert not env
#     356     del master
#
# /usr/local/Caskroom/miniconda/base/envs/numpyro-stein/lib/python3.8/site-packages/jax/linear_util.py in call_wrapped(self, *args, **kwargs)
#     147     gen = None
#     148
# --> 149     ans = self.f(*args, **dict(self.params, **kwargs))
#     150     del args
#     151     while stack:
#
# /usr/local/Caskroom/miniconda/base/envs/numpyro-stein/lib/python3.8/site-packages/numpyro/infer/util.py in potential_energy(model, inv_transforms, model_args, model_kwargs, params)
#     155     """
#     156     params_constrained = transform_fn(inv_transforms, params)
# --> 157     log_joint, model_trace = log_density(model, model_args, model_kwargs, params_constrained,
#     158                                          skip_dist_transforms=True)
#     159     for name, t in inv_transforms.items():
#
# /usr/local/Caskroom/miniconda/base/envs/numpyro-stein/lib/python3.8/site-packages/numpyro/infer/util.py in log_density(model, model_args, model_kwargs, params, skip_dist_transforms)
#      59     else:
#      60         model = substitute(model, param_map=params)
# ---> 61     model_trace = trace(model).get_trace(*model_args, **model_kwargs)
#      62     log_joint = 0.
#      63     for site in model_trace.values():
#
# /usr/local/Caskroom/miniconda/base/envs/numpyro-stein/lib/python3.8/site-packages/numpyro/handlers.py in get_trace(self, *args, **kwargs)
#     147         :return: `OrderedDict` containing the execution trace.
#     148         """
# --> 149         self(*args, **kwargs)
#     150         return self.trace
#     151
#
# /usr/local/Caskroom/miniconda/base/envs/numpyro-stein/lib/python3.8/site-packages/numpyro/primitives.py in __call__(self, *args, **kwargs)
#      61     def __call__(self, *args, **kwargs):
#      62         with self:
# ---> 63             return self.fn(*args, **kwargs)
#      64
#      65
#
# /usr/local/Caskroom/miniconda/base/envs/numpyro-stein/lib/python3.8/site-packages/numpyro/primitives.py in __call__(self, *args, **kwargs)
#      61     def __call__(self, *args, **kwargs):
#      62         with self:
# ---> 63             return self.fn(*args, **kwargs)
#      64
#      65
#
# /usr/local/Caskroom/miniconda/base/envs/numpyro-stein/lib/python3.8/site-packages/numpyro/primitives.py in __call__(self, *args, **kwargs)
#      61     def __call__(self, *args, **kwargs):
#      62         with self:
# ---> 63             return self.fn(*args, **kwargs)
#      64
#      65
#
# /usr/local/Caskroom/miniconda/base/envs/numpyro-stein/lib/python3.8/site-packages/numpyro/primitives.py in __call__(self, *args, **kwargs)
#      61     def __call__(self, *args, **kwargs):
#      62         with self:
# ---> 63             return self.fn(*args, **kwargs)
#      64
#      65
#
# <ipython-input-26-f06216e53a2c> in model()
#       1 def model():
# ----> 2     numpyro.sample('x', Star())
#       3 guide = AutoDelta(model, init_strategy=init_with_noise(init_to_value({'x': np.array([0., 0.])}), noise_scale=3.0))
#
# /usr/local/Caskroom/miniconda/base/envs/numpyro-stein/lib/python3.8/site-packages/numpyro/primitives.py in sample(name, fn, obs, rng_key, sample_shape)
#     103
#     104     # ...and use apply_stack to send it to the Messengers
# --> 105     msg = apply_stack(initial_msg)
#     106     return msg['value']
#     107
#
# /usr/local/Caskroom/miniconda/base/envs/numpyro-stein/lib/python3.8/site-packages/numpyro/primitives.py in apply_stack(msg)
#      27     if msg['value'] is None:
#      28         if msg['type'] == 'sample':
# ---> 29             msg['value'], msg['intermediates'] = msg['fn'](*msg['args'],
#      30                                                            sample_intermediates=True,
#      31                                                            **msg['kwargs'])
#
# /usr/local/Caskroom/miniconda/base/envs/numpyro-stein/lib/python3.8/site-packages/numpyro/distributions/distribution.py in __call__(self, *args, **kwargs)
#     214         sample_intermediates = kwargs.pop('sample_intermediates', False)
#     215         if sample_intermediates:
# --> 216             return self.sample_with_intermediates(key, *args, **kwargs)
#     217         return self.sample(key, *args, **kwargs)
#     218
#
# /usr/local/Caskroom/miniconda/base/envs/numpyro-stein/lib/python3.8/site-packages/numpyro/distributions/distribution.py in sample_with_intermediates(self, key, sample_shape)
#     172         :rtype: numpy.ndarray
#     173         """
# --> 174         return self.sample(key, sample_shape=sample_shape), []
#     175
#     176     def transform_with_intermediates(self, base_value):
#
# <ipython-input-35-15adf8dc1272> in sample(self, key, sample_shape)
#      27     def sample(self, key, sample_shape=()):
#      28         print(key)
# ---> 29         zs = dist.Categorical(probs=np.array([1/self.n_comp] * self.n_comp)).sample(key, sample_shape)
#      30         xs = np.stack([dist.MultivariateNormal(self.mus[i], self.covs[i]).sample(key, sample_shape)
#      31                        for i in range(self.n_comp)], axis=0)
#
# /usr/local/Caskroom/miniconda/base/envs/numpyro-stein/lib/python3.8/site-packages/numpyro/distributions/discrete.py in sample(self, key, sample_shape)
#     228
#     229     def sample(self, key, sample_shape=()):
# --> 230         return categorical(key, self.probs, shape=sample_shape + self.batch_shape)
#     231
#     232     @validate_sample
#
# /usr/local/Caskroom/miniconda/base/envs/numpyro-stein/lib/python3.8/site-packages/numpyro/distributions/util.py in categorical(key, p, shape)
#      44
#      45 def categorical(key, p, shape=()):
# ---> 46     return _categorical(key, p, shape)
#      47
#      48
#
# /usr/local/Caskroom/miniconda/base/envs/numpyro-stein/lib/python3.8/site-packages/jax/api.py in f_jitted(*args, **kwargs)
#     129   def f_jitted(*args, **kwargs):
#     130     if _thread_local_state.jit_is_disabled or config.read('jax_disable_jit'):
# --> 131       return fun(*args, **kwargs)
#     132     if static_argnums and max(static_argnums) >= len(args):
#     133       msg = ("Jitted function has static_argnums={} but was called with only {}"
#
# /usr/local/Caskroom/miniconda/base/envs/numpyro-stein/lib/python3.8/site-packages/numpyro/distributions/util.py in _categorical(key, p, shape)
#      37     shape = shape or p.shape[:-1]
#      38     s = cumsum(p)
# ---> 39     r = random.uniform(key, shape=shape + (1,))
#      40     # FIXME: replace this computation by using binary search as suggested in the above
#      41     # reference. A while_loop + vmap for a reshaped 2D array would be enough.
#
# /usr/local/Caskroom/miniconda/base/envs/numpyro-stein/lib/python3.8/site-packages/jax/random.py in uniform(key, shape, dtype, minval, maxval)
#     320   dtype = dtypes.canonicalize_dtype(dtype)
#     321   shape = abstract_arrays.canonicalize_shape(shape)
# --> 322   return _uniform(key, shape, dtype, minval, maxval)
#     323
#     324 @partial(jit, static_argnums=(1, 2))
#
# /usr/local/Caskroom/miniconda/base/envs/numpyro-stein/lib/python3.8/site-packages/jax/api.py in f_jitted(*args, **kwargs)
#     129   def f_jitted(*args, **kwargs):
#     130     if _thread_local_state.jit_is_disabled or config.read('jax_disable_jit'):
# --> 131       return fun(*args, **kwargs)
#     132     if static_argnums and max(static_argnums) >= len(args):
#     133       msg = ("Jitted function has static_argnums={} but was called with only {}"
#
# /usr/local/Caskroom/miniconda/base/envs/numpyro-stein/lib/python3.8/site-packages/jax/random.py in _uniform(key, shape, dtype, minval, maxval)
#     336     raise TypeError("uniform only accepts 32- or 64-bit dtypes.")
#     337
# --> 338   bits = _random_bits(key, nbits, shape)
#     339
#     340   # The strategy here is to randomize only the mantissa bits with an exponent of
#
# /usr/local/Caskroom/miniconda/base/envs/numpyro-stein/lib/python3.8/site-packages/jax/random.py in _random_bits(key, bit_width, shape)
#     269   """Sample uniform random bits of given width and shape using PRNG key."""
#     270   if not _is_prng_key(key):
# --> 271     raise TypeError("_random_bits got invalid prng key.")
#     272   if bit_width not in (32, 64):
#     273     raise TypeError("requires 32- or 64-bit field width.")
#
# TypeError: _random_bits got invalid prng key.
